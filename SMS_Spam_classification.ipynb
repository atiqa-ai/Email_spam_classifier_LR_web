# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('spam.csv',encoding='latin1')

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 680   ham     What is this 'hex' place you talk of? Explain!        NaN
# 4554  ham  7 wonders in My WORLD 7th You 6th Ur style 5th...        NaN
# 3839  ham  HEY MATE! HOWS U HONEY?DID U AVE GOOD HOLIDAY?...        NaN
# 2026  ham  Nah man, my car is meant to be crammed full of...        NaN
# 1341  ham  Just chill for another 6hrs. If you could slee...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 680         NaN        NaN
# 4554        NaN        NaN
# 3839        NaN        NaN
# 2026        NaN        NaN
# 1341        NaN        NaN

# %%
df.info()  #dataset info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.shape  #shape of data
# Out:
# (5572, 2)

# %% [markdown]
# ## Data preprocessing

# %%
df.rename(columns={'v1':'output','v2':'text'},inplace=True)
df.head()
# Out:
#   output                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# ### data encoding

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
df['output']=encoder.fit_transform(df['output'])   #making label encoders of output
df.head(3)
# Out:
#    output                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...

# %%
df.isna().sum()
# Out:
# output    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()  #checking for duplicates
# Out:
# np.int64(403)

# %%
#removing duplicates
df=df.drop_duplicates(keep='first')

# %%
df.head(3)  
#database after removing duplicates messages
# Out:
#    output                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...

# %%
# checking no of hams and spams msgs
df['output'].value_counts()
# 0: hams
#1: spams
# Out:
# output
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['output'].value_counts(),labels=['ham','spam'],autopct="%0.2f")  #percentage of ham and spam msgs
plt.show()

# %%
# Data is imbalance

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\premier\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\premier\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\premier\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\premier\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\premier\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\premier\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\premier\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
df['num_characters']=df['text'].apply(len)   #defines no of characters into msg
df.head()
# Out:
#    output                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
#num of words into sentence
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))  #counting words into a sentence

# %%
df.head()
# Out:
#    output                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         24
# 1          8
# 2         37
# 3         13
# 4         15

# %%
#it breaks sentence into parts on the basis of sentences
df['num_sent']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))  #counting words into a sentence

# %%
df.head()
# Out:
#    output                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sent
# 0         24         2
# 1          8         2
# 2         37         2
# 3         13         1
# 4         15         1

# %%
df[['num_characters','num_words','num_sent']].describe()
# Out:
#        num_characters    num_words     num_sent
# count     5169.000000  5169.000000  5169.000000
# mean        78.977945    18.455794     1.965564
# std         58.236293    13.324758     1.448541
# min          2.000000     1.000000     1.000000
# 25%         36.000000     9.000000     1.000000
# 50%         60.000000    15.000000     1.000000
# 75%        117.000000    26.000000     2.000000
# max        910.000000   220.000000    38.000000

# %%
df[['num_characters','num_words','num_sent']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5169 entries, 0 to 5571
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   num_characters  5169 non-null   int64
#  1   num_words       5169 non-null   int64
#  2   num_sent        5169 non-null   int64
# dtypes: int64(3)
# memory usage: 161.5 KB

# %%
df[df['output'] == 0][['num_characters','num_words','num_sent']].describe()  # to check characteristics of ham msgs
# Out:
#        num_characters    num_words     num_sent
# count     4516.000000  4516.000000  4516.000000
# mean        70.459256    17.123782     1.820195
# std         56.358207    13.493970     1.383657
# min          2.000000     1.000000     1.000000
# 25%         34.000000     8.000000     1.000000
# 50%         52.000000    13.000000     1.000000
# 75%         90.000000    22.000000     2.000000
# max        910.000000   220.000000    38.000000

# %%
df[df['output'] == 1][['num_characters','num_words','num_sent']].describe()  # to check characteristics of spam msgs
# Out:
#        num_characters   num_words    num_sent
# count      653.000000  653.000000  653.000000
# mean       137.891271   27.667688    2.970904
# std         30.137753    7.008418    1.488425
# min         13.000000    2.000000    1.000000
# 25%        132.000000   25.000000    2.000000
# 50%        149.000000   29.000000    3.000000
# 75%        157.000000   32.000000    4.000000
# max        224.000000   46.000000    9.000000

# %%
# histogram
import seaborn as sns
sns.histplot(df[df['output']== 0]['num_characters'])
sns.histplot(df[df['output']== 1]['num_characters'])
plt.show()

# %%
sns.countplot(x='output', data=df, color='green')
plt.title('Category Distribution')
plt.show()

# %%
sns.pairplot(df,hue='output')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#heat map of numerical data values
numeric_df = df.select_dtypes(include=['int64', 'float64'])
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Data preprocessing

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\premier\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')   #stopwords
import string

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def transform_text(text):
    text=text.lower()   #converts text into lower case
    text=nltk.word_tokenize(text)   #splits text into words

    y=[]
    for i in text:
        if i.isalnum ():   #removing special characters
         y.append(i)

    text=y[:]  #copying list here 
    y.clear()

    for i in text:
        if i not in stopwords.words('english')and i not in string.punctuation:
         y.append(i)

    text=y[:]
    y.clear()
    
    for i in text:
      y.append(ps.stem(i))   #word stemming
    
    return  " ".join(y)

# %%
transform_text('hi its me alarming point here?')
# Out:
# 'hi alarm point'

# %%
df['transformed text']=df['text'].apply(transform_text)

# %%
df.head(3)
# Out:
#    output                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
#
#    num_words  num_sent                                   transformed text
# 0         24         2  go jurong point crazi avail bugi n great world...
# 1          8         2                              ok lar joke wif u oni
# 2         37         2  free entri 2 wkli comp win fa cup final tkt 21...

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\premier\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\premier\anaconda3\lib\site-packages (from wordcloud) (2.1.3)
# Requirement already satisfied: pillow in c:\users\premier\anaconda3\lib\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\premier\anaconda3\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\premier\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\premier\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\premier\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\premier\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\premier\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\premier\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\premier\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\premier\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %% [markdown]
# ### Word cloud of spam and ham  msgs
# ## Ham word cloud

# %%
from wordcloud import WordCloud

wc = WordCloud(
    width=500,
    height=500,
    min_font_size=10,
    background_color='white'   #spam messages wordcloud
)

# %%
spam_wc=wc.generate(df[df['output']==1]['transformed text'].str.cat(sep=" "))

# %%
plt.imshow(spam_wc)

# %% [markdown]
# ## Ham word cloud

# %%
Ham_wc=wc.generate(df[df['output']==0]['transformed text'].str.cat(sep=" "))
plt.imshow(Ham_wc)

# %% [markdown]
# ## Finding mostly used  keywords in spam messages

# %%
spam_corpus=[]
for msg in df[df['output']==1]['transformed text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 9939

# %%
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Count top 35 words in spam corpus
word_count = pd.DataFrame(Counter(spam_corpus).most_common(35))  #count occuring of spam msgs and then convert it into dataframe
word_count.columns = ['word', 'count']  

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x='count', y='word', data=word_count)
plt.xticks(rotation='horizontal')
plt.show()

# %% [markdown]
# ### Mostly ised keywords in Ham messages

# %%
Ham_corpus=[]
for msg in df[df['output']==0]['transformed text'].tolist():
    for word in msg.split():
        Ham_corpus.append(word)

# %%
len(Ham_corpus)
# Out:
# 35404

# %%
# Count top 35 words in spam corpus
word_count = pd.DataFrame(Counter(Ham_corpus).most_common(35))  #count occuring of spam msgs and then convert it into dataframe
word_count.columns = ['word', 'count']  

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x='count', y='word', data=word_count)
plt.xticks(rotation='horizontal')
plt.show()

# %% [markdown]
# ## Model Building and training

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
Mnb=MultinomialNB()
Bnb=BernoulliNB()

# %% [markdown]
# ## Model training using tfidf vectorizer

# %% [markdown]
# ## multimodel naive bayes model training

# %% [markdown]
# ## Guassian naive bayes model

# %%
X_2 = tfidf.fit_transform(df['transformed text']).toarray()
y_2=df['output'].values

# %%
X_2.shape
# Out:
# (5169, 3000)

# %%
y_2.shape
# Out:
# (5169,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_2_train,X_2_test,y_2_train,y_2_test=train_test_split(X_2, y_2,test_size=0.2, random_state=42)

# %% [markdown]
# ## Guassian model by tfidf

# %%
gnb.fit(X_2_train, y_2_train)
y2_pred1=gnb.predict(X_2_test)
print(f"Accuracy : {accuracy_score(y_2_test,y2_pred1)}")
print(f"Conusion matrix:\n {confusion_matrix(y_2_test,y2_pred1)}")
print(f"precision score:{precision_score(y_2_test,y2_pred1)}")
# Out:
# Accuracy : 0.8626692456479691
# Conusion matrix:
#  [[771 118]
#  [ 24 121]]
# precision score:0.5062761506276151

# %% [markdown]
# ## Multinomial model by tfidf

# %%
Mnb.fit(X_2_train, y_2_train)
y2_pred2=Mnb.predict(X_2_test)
print(f"Accuracy : {accuracy_score(y_2_test,y2_pred2)}")
print(f"Conusion matrix:\n {confusion_matrix(y_2_test,y2_pred2)}")
print(f"precision score:{precision_score(y_2_test,y2_pred2)}")
# Out:
# Accuracy : 0.9729206963249516
# Conusion matrix:
#  [[888   1]
#  [ 27 118]]
# precision score:0.9915966386554622

# %% [markdown]
# ## Bernoulli model by tfidf

# %%
Bnb.fit(X_2_train, y_2_train)
y2_pred3=Bnb.predict(X_2_test)
print(f"Accuracy : {accuracy_score(y_2_test,y2_pred3)}")
print(f"Conusion matrix:\n {confusion_matrix(y_2_test,y2_pred3)}")
print(f"precision score:{precision_score(y_2_test,y2_pred3)}")
# Out:
# Accuracy : 0.9729206963249516
# Conusion matrix:
#  [[884   5]
#  [ 23 122]]
# precision score:0.9606299212598425

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\premier\anaconda3\lib\site-packages (3.1.1)
# Requirement already satisfied: numpy in c:\users\premier\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\premier\anaconda3\lib\site-packages (from xgboost) (1.15.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Multimodels using here

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    #'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9323017408123792
# Precision -  0.7737226277372263
# For  KN
# Accuracy -  0.9042553191489362
# Precision -  1.0
# For  NB
# Accuracy -  0.9738878143133463
# Precision -  0.8881578947368421
# For  DT
# Accuracy -  0.9245647969052224
# Precision -  0.935064935064935
# For  LR
# Accuracy -  0.9709864603481625
# Precision -  0.9457364341085271
# For  RF
# Accuracy -  0.9671179883945842
# Precision -  1.0
# For  ETC
# Accuracy -  0.971953578336557
# Precision -  0.9915254237288136
# For  GBDT
# Accuracy -  0.9342359767891683
# Precision -  0.8811881188118812
# For  xgb
# Accuracy -  0.9700193423597679
# Precision -  0.9453125

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#   Algorithm  Accuracy  Precision
# 1        KN  0.904255   1.000000
# 5        RF  0.967118   1.000000
# 6       ETC  0.971954   0.991525
# 4        LR  0.970986   0.945736
# 8       xgb  0.970019   0.945312
# 3        DT  0.924565   0.935065
# 2        NB  0.973888   0.888158
# 7      GBDT  0.934236   0.881188
# 0       SVC  0.932302   0.773723

# %%
# Applying stacking
estimators=[('svm', svc), ('nb', mnb), ('et', etc)]
final_estimator=RandomForestClassifier()

# %%
from sklearn.ensemble import StackingClassifier

# %%
clf = StackingClassifier(estimators=estimators, final_estimator=final_estimator)

# %%
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print("Accuracy",accuracy_score(y_test,y_pred))
print("Precision",precision_score(y_test,y_pred))
# Out:
# Accuracy 0.9854932301740812
# Precision 0.9850746268656716

# %%
import pickle
pickle.dump(tfidf,open('vectorizer.pkl','wb'))
pickle.dump(Mnb,open('model.pkl','wb'))
